# %%
#Student ID 1002080520
import numpy as np
from numpy import loadtxt
import csv

#CODE TO TAKE THE DATA AND STORE IN THE VARIABLE

file = open('q2_cde_dataset.csv')
csvreader = csv.reader(file, delimiter = ",")
data = []
for row in csvreader:
    data.append(row)

program_data = []
for i in range(0 , len(data)):
    col= []
    for j in range(0,len(data[i])):
        if j==len(data[i])-1:
            col.append(data[i][j])
        else:
            col.append(float(data[i][j]))
    program_data.append(col)
file.close()
print("\n\nProgram Data \n\n")
print(program_data)

#We have successfully imported the data
# Out:
# Program Data
#
#
# [[0.088806749762916, 0.098008394324455, 0.57649058735898, 3.239527050286, ' Ceramic'], [0.078963683508211, 0.085300149997219, 0.27162441732486, 3.4442845617291, ' Metal'], [0.1317769211421, 0.070414892852672, 0.50961174676178, 3.984839303975, ' Ceramic'], [0.12238449845956, 0.081946645569603, 0.64441296678112, 3.4343857831642, ' Ceramic'], [0.11207208488382, 0.15, 0.3736066136156, 2.4684426455694, ' Plastic'], [0.11696836534332, 0.1192966406841, 0.3315496717105, 1.8135585032895, ' Plastic'], [0.12666802764538, 0.15, 0.41499442802485, 2.9562056990404, ' Plastic'], [0.10444296796273, 0.10662125348196, 0.29055615215118, 3.4594532366829, ' Plastic'], [0.13065405525064, 0.14162609670298, 0.33516279766318, 2.759442528738, ' Plastic'], [0.11931866537973, 0.10053257281629, 0.29777585695821, 4.0332186383189, ' Plastic'], [0.082429457069664, 0.03, 0.13468307216616, 1.6519180922721, ' Ceramic'], [0.091479158720172, 0.060070441860045, 0.19527332743138, 3.6252435307061, ' Metal'], [0.071660045050914, 0.068186655985927, 0.20326252583045, 3.3387336593187, ' Metal'], [0.076470494832748, 0.037424113599498, 0.14517371741585, 3.8657063272988, ' Metal'], [0.071541180684419, 0.046722582104868, 0.14136615592985, 3.6014732414822, ' Metal'], [0.056861019101979, 0.039210654840189, 0.1, 4.2529027176783, ' Metal'], [0.092920294206209, 0.087584465067116, 0.51515446767606, 3.0913043059905, ' Ceramic'], [0.10863776571637, 0.09937991444001, 0.26024722221002, 2.9049531726125, ' Plastic'], [0.06703118305467, 0.034837520954406, 0.17981929843221, 3.6361751033213, ' Ceramic'], [0.10845778067775, 0.15, 0.30631831930939, 2.7225151859995, ' Plastic'], [0.10351158783244, 0.090147254995561, 0.37797606110704, 2.2236204476526, ' Metal'], [0.05793415728801, 0.093971546585003, 0.26263698540886, 3.0755799742869, ' Metal'], [0.082216621103185, 0.03, 0.18961277224592, 3.6783807762181, ' Ceramic'], [0.084626246895992, 0.088276312728258, 0.34135824058213, 5.132612237101, ' Metal'], [0.080747231856961, 0.039582830338036, 0.15597198229869, 1.9519207850514, ' Metal'], [0.081714521728662, 0.078173468129055, 0.37083915011061, 4.9288470464169, ' Ceramic'], [0.10418957884247, 0.066167647680057, 0.47586304955948, 2.7880351473874, ' Ceramic'], [0.073195186431948, 0.069653374554906, 0.26294981341864, 2.1557577814632, ' Ceramic'], [0.07, 0.083862070705446, 0.12933829285419, 4.9811674714121, ' Plastic'], [0.096821312565705, 0.11009940712145, 0.43350062267488, 3.4057425529038, ' Metal'], [0.093002970285131, 0.10464386637093, 0.43050162728775, 1.6026869261643, ' Metal'], [0.11943668873498, 0.095372847230543, 0.66824281745704, 4.7699058293472, ' Ceramic'], [0.087662575770243, 0.098889957563115, 0.35883373665274, 2.2133895614484, ' Metal'], [0.12476736552975, 0.13961000347712, 0.34280233510762, 2.8783923064871, ' Plastic'], [0.062746024559154, 0.045413541434605, 0.15581607127816, 3.0031434624986, ' Ceramic'], [0.10956945660439, 0.074212465053041, 0.36381957535576, 2.0970309906985, ' Metal'], [0.078601495794935, 0.095495149866535, 0.28026108526178, 2.2032864485297, ' Metal'], [0.088169860795162, 0.1411927728824, 0.33056587912885, 2.2608116068527, ' Plastic'], [0.13536770983871, 0.15, 0.45257263657253, 2.9508038321694, ' Plastic'], [0.10061331331862, 0.119774291429, 0.32034644489206, 2.920028412513, ' Plastic'], [0.10233285498915, 0.10053409594951, 0.209517648258, 3.4790599447684, ' Plastic'], [0.077570208329599, 0.071210448924676, 0.28627049474791, 2.91467330895, ' Ceramic'], [0.086754750885729, 0.099616835247918, 0.371925962112, 3.7908681861345, ' Metal'], [0.16486699457048, 0.11806438151643, 0.44603734059307, 3.2034649808365, ' Plastic'], [0.10697697137327, 0.10078433630139, 0.2439524436531, 4.0955927900359, ' Plastic'], [0.082311872833235, 0.079915616652095, 0.46140762788105, 4.621383363501, ' Ceramic'], [0.080431700282496, 0.079693252073303, 0.32328034905731, 4.0586529976888, ' Metal'], [0.083336597559058, 0.07023925704915, 0.22927271481365, 3.4106954907438, ' Metal'], [0.083925602197308, ...

# %%
#Training the program data by giving data itself and predicting
Train_program_data = program_data
Distance =[]
for i in range(0 , len(Train_program_data)):
    col = []
    for j in range(0,len(Train_program_data)):
        if i==j:
             j=j+1
        else:
                dist_label =[]
                dist_label.append(Train_program_data[j][4])
                X=Train_program_data[i][0]
                Y=Train_program_data[i][1]
                Z=Train_program_data[i][2]
                W=Train_program_data[i][3]
                x=Train_program_data[j][0]
                y=Train_program_data[j][1]
                z=Train_program_data[j][2]
                w=Train_program_data[j][3]
                dist = np.sqrt((X-x)**2 + (Y-y)**2 + (Z-z)**2 + (W-w)**2)
                dist_label.append(dist)
                col.append(dist_label)
    Distance.append(col)
print("\n DISTANCE MATRIX \n")
print(Distance)
print("\n")

# %%
#We have measured the distances and also labeled the points now we need to extract the distance arrange it into 
#ascending order and the again attached the labels so that we can get newly trained data set
def bubblesort(arr):   
    n = len(arr)
    # For loop to traverse through all
    # element in an array
    for i in range(n):
        for j in range(0, n - i - 1):
             
            # Range of the array is from 0 to n-i-1
            # Swap the elements if the element found
            #is greater than the adjacent element
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                
only_dist =[]
for i in range(0, len(Distance)):
    cols=[]
802921899, 1.365076429166825, 1.3774983813037371, 1.3867734097409654, 1.4014714551443568, 1.4383279336796557, 1.4436529389319852, 1.4472831841789613, 1.4787167758740265, 1.495556259257986, 1.5096538194645297, 1.533434973645356, 1.5399223782048683, 1.6433563235504869, 1.649351962319602, 1.6588256467554225, 1.7019219391516434, 1.7280110009367713, 1.7982798289726143, 1.8667377961090337, 1.9076611164081496, 1.992510372845375, 1.9977845728287211, 2.179121666757141, 2.319392420464229], [0.04113736347299701, 0.04483821888484951, 0.056283614568920844, 0.07645109099572855, 0.10487930312535064, 0.11110558501626927, 0.12712417559352215, 0.12728958855290012, 0.13468994310090612, 0.15608144421563425, 0.16371257853259638, 0.16918419066886864, 0.17636995850660556, 0.18974901129007732, 0.19841575712026863, 0.20789136104425207, 0.20874547193021278, 0.21894981457956952, 0.22627928218593124, 0.25415671496017106, 0.2853792832475289, 0.2856989706824388, 0.29100051141611954, 0.2953147919468455, 0.3112343362528553, 0.3437871752031129, 0.36117347189421145, 0.36759679752524954, 0.36951492639025607, 0.3718789595746973, 0.3754542603111126, 0.4108291906107159, 0.41996744882796105, 0.42907103309692124, 0.4314983495602957, 0.43903318760963317, 0.44258831305660246, 0.4581167934585907, 0.5150123408342268, 0.5280866584752342, 0.5300028755615546, 0.532572035758873, 0.5404503481142214, 0.5434336672012964, 0.550771398269766, 0.5747589738268596, 0.5910903447277469, 0.5931679418905589, 0.6086095139828762, 0.6165634620736904, 0.6336945867069608, 0.6431129476988683, 0.6487333106686897, 0.6526811248301472, 0.6664645184225494, 0.6686302534583772, 0.6873549947519254, 0.6880255163591127, 0.6920189612507524, 0.726092742653607, 0.8174913779509325, 0.8188304903339031, 0.8259016172385526, 0.8282095339287435, 0.8344889108819087, 0.8372214991461376, 0.8471209099977837, 0.84795472044108, 0.8525624528861806, 0.8690936263198773, 0.9314646285438829, 0.9548460029911275, 0.9819710923081226, 0.9838445255865116, 1.0452805346563305, 1.0489659138142915, 1.0981609803642844, 1.1049910394267621, 1.1382773140112714, 1.13997792448106 ...

# %%
#We have arranged the distance in ascending order now we will label it
data_dist_label=[]
for i in range(0 , len(only_dist)):
    cols=[]
    for j in range(0 , len(only_dist[i])):
        for h in range(0 , len(only_dist[i])):
            if only_dist[i][j]==Distance[i][h][1]:
                d = Distance[i][h][0]
                break
        cols.append(d)
    data_dist_label.append(cols)

print(data_dist_label)

#We have successfully generated the distance label in ascending order
# Out:
# [[' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Metal', ' Metal'], [' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal'], [' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Pl ...

# %%
#We will now predict by K nearest Neighbours
predict_1 = []
for i in range(0 , len(data_dist_label)):
     predict_1.append(data_dist_label[i][0])
print(predict_1)
# Out:
# [' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic']

# %%
#We will now find the accuracy for K=1
ps=0 #predicted Successfully
pu=0 #Predicted Unsuccessfully
for i in range(0,len(program_data)):
    if predict_1[i] == program_data[i][4]:
            ps=ps+1
    else :
        pu=pu+1
accuracy_1 = ps/(ps+pu)
print("\nAccuracy for KNN with 1 neighbour")
print("Predicted unsuccesfully  "+str(pu))
print("Predicted Successfully  " + str(ps))
print("Accuracy "+str(accuracy_1*100)+"%")
# Out:
# Accuracy for KNN with 1 neighbour
# Predicted unsuccesfully  58
# Predicted Successfully  62
# Accuracy 51.66666666666667%

# %%
a = " Metal"
b = " Plastic"
c = " Ceramic"

#We will now intialize the predictions for KNN value 3
predict_3 =[]
for i in range(0 , len(data_dist_label)):
    x=0
    y=0
    z=0
    cols=[]
    for j in range(0 , 3):
        if (str(data_dist_label[i][j]) == a):
            x=x+1
        if(str(data_dist_label[i][j])==b):
            y=y+1
        if(str(data_dist_label[i][j])==c):
            z=z+1
 
    if (x >= y) and (y >= z):
           largest = a
    elif (y >= x) and (y >= z):
        largest = b
    else:
        largest = c
    predict_3.append(largest)
print(predict_3)
# Out:
# [' Metal', ' Metal', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic']

# %%
#Now we will find the accuracy for KNN with 3 neighbours

ps=0 #predicted Successfully
pu=0 #Predicted Unsuccessfully
for i in range(0,len(program_data)):
    if predict_3[i] == program_data[i][4]:
            ps=ps+1
    else :
        pu=pu+1
accuracy_1 = ps/(ps+pu)
print("\nAccuracy for KNN with 3 neighbour")
print("Predicted unsuccesfully  "+str(pu))
print("Predicted Successfully  " + str(ps))
print("Accuracy "+str(accuracy_1*100)+"%")
# Out:
# Accuracy for KNN with 3 neighbour
# Predicted unsuccesfully  58
# Predicted Successfully  62
# Accuracy 51.66666666666667%

# %%
#We will now intialize the predictions for KNN value 3
predict_5 =[]
for i in range(0 , len(data_dist_label)):
    x=0
    y=0
    z=0
    cols=[]
    for j in range(0 , 5):
        if (str(data_dist_label[i][j]) == a):
            x=x+1
        if(str(data_dist_label[i][j])==b):
            y=y+1
        if(str(data_dist_label[i][j])==c):
            z=z+1
 
    if (x >= y) and (y >= z):
           largest = a
    elif (y >= x) and (y >= z):
        largest = b
    else:
        largest = c
    predict_5.append(largest)
print(predict_5)
# Out:
# [' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic']

# %%
#Now we will find the accuracy for KNN with 3 neighbours

ps=0 #predicted Successfully
pu=0 #Predicted Unsuccessfully
for i in range(0,len(program_data)):
    if predict_5[i] == program_data[i][4]:
            ps=ps+1
    else :
        pu=pu+1
accuracy_1 = ps/(ps+pu)
print("\nAccuracy for KNN with 5 neighbour")
print("Predicted unsuccesfully  "+str(pu))
print("Predicted Successfully  " + str(ps))
print("Accuracy "+str(accuracy_1*100)+"%")
# Out:
# Accuracy for KNN with 5 neighbour
# Predicted unsuccesfully  57
# Predicted Successfully  63
# Accuracy 52.5%

# %% [markdown]
# Hence we can see that 5 neighbours we have more accuracy then with 1 and 3 neighbours
