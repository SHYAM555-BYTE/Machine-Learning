# %%
#Student ID 1002080520
import numpy as np
from numpy import loadtxt
import csv

#CODE TO TAKE THE DATA AND STORE IN THE VARIABLE

file = open('q2_cde_dataset.csv')
csvreader = csv.reader(file, delimiter = ",")
data = []
for row in csvreader:
    data.append(row)

program_data = []
for i in range(0 , len(data)):
    col= []
    for j in range(0,len(data[i])):
        if j==len(data[i])-1:
            col.append(data[i][j])
        elif j==3:
            j=j+1
        else:
            col.append(float(data[i][j]))
    program_data.append(col)
file.close()
print("\n\nProgram Data \n\n")
print(program_data)

#We have successfully imported the data without the fourth feature in given data file
# Out:
# Program Data
#
#
# [[0.088806749762916, 0.098008394324455, 0.57649058735898, ' Ceramic'], [0.078963683508211, 0.085300149997219, 0.27162441732486, ' Metal'], [0.1317769211421, 0.070414892852672, 0.50961174676178, ' Ceramic'], [0.12238449845956, 0.081946645569603, 0.64441296678112, ' Ceramic'], [0.11207208488382, 0.15, 0.3736066136156, ' Plastic'], [0.11696836534332, 0.1192966406841, 0.3315496717105, ' Plastic'], [0.12666802764538, 0.15, 0.41499442802485, ' Plastic'], [0.10444296796273, 0.10662125348196, 0.29055615215118, ' Plastic'], [0.13065405525064, 0.14162609670298, 0.33516279766318, ' Plastic'], [0.11931866537973, 0.10053257281629, 0.29777585695821, ' Plastic'], [0.082429457069664, 0.03, 0.13468307216616, ' Ceramic'], [0.091479158720172, 0.060070441860045, 0.19527332743138, ' Metal'], [0.071660045050914, 0.068186655985927, 0.20326252583045, ' Metal'], [0.076470494832748, 0.037424113599498, 0.14517371741585, ' Metal'], [0.071541180684419, 0.046722582104868, 0.14136615592985, ' Metal'], [0.056861019101979, 0.039210654840189, 0.1, ' Metal'], [0.092920294206209, 0.087584465067116, 0.51515446767606, ' Ceramic'], [0.10863776571637, 0.09937991444001, 0.26024722221002, ' Plastic'], [0.06703118305467, 0.034837520954406, 0.17981929843221, ' Ceramic'], [0.10845778067775, 0.15, 0.30631831930939, ' Plastic'], [0.10351158783244, 0.090147254995561, 0.37797606110704, ' Metal'], [0.05793415728801, 0.093971546585003, 0.26263698540886, ' Metal'], [0.082216621103185, 0.03, 0.18961277224592, ' Ceramic'], [0.084626246895992, 0.088276312728258, 0.34135824058213, ' Metal'], [0.080747231856961, 0.039582830338036, 0.15597198229869, ' Metal'], [0.081714521728662, 0.078173468129055, 0.37083915011061, ' Ceramic'], [0.10418957884247, 0.066167647680057, 0.47586304955948, ' Ceramic'], [0.073195186431948, 0.069653374554906, 0.26294981341864, ' Ceramic'], [0.07, 0.083862070705446, 0.12933829285419, ' Plastic'], [0.096821312565705, 0.11009940712145, 0.43350062267488, ' Metal'], [0.093002970285131, 0.10464386637093, 0.43050162728775, ' Metal'], [0.11943668873498, 0.095372847230543, 0.66824281745704, ' Ceramic'], [0.087662575770243, 0.098889957563115, 0.35883373665274, ' Metal'], [0.12476736552975, 0.13961000347712, 0.34280233510762, ' Plastic'], [0.062746024559154, 0.045413541434605, 0.15581607127816, ' Ceramic'], [0.10956945660439, 0.074212465053041, 0.36381957535576, ' Metal'], [0.078601495794935, 0.095495149866535, 0.28026108526178, ' Metal'], [0.088169860795162, 0.1411927728824, 0.33056587912885, ' Plastic'], [0.13536770983871, 0.15, 0.45257263657253, ' Plastic'], [0.10061331331862, 0.119774291429, 0.32034644489206, ' Plastic'], [0.10233285498915, 0.10053409594951, 0.209517648258, ' Plastic'], [0.077570208329599, 0.071210448924676, 0.28627049474791, ' Ceramic'], [0.086754750885729, 0.099616835247918, 0.371925962112, ' Metal'], [0.16486699457048, 0.11806438151643, 0.44603734059307, ' Plastic'], [0.10697697137327, 0.10078433630139, 0.2439524436531, ' Plastic'], [0.082311872833235, 0.079915616652095, 0.46140762788105, ' Ceramic'], [0.080431700282496, 0.079693252073303, 0.32328034905731, ' Metal'], [0.083336597559058, 0.07023925704915, 0.22927271481365, ' Metal'], [0.083925602197308, 0.099584639004556, 0.52002756216913, ' Ceramic'], [0.10013689773759, 0.054012382342326, 0.10363452463641, ' Plastic'], [0.12476189307784, 0.048603105895821, 0.18812990223109, ' Plastic'], [0.080483146934743, 0.083567636221028, 0.42230974623879, ' Ceramic'], [0.077202906180326, 0.042235396174331, 0.14109241777498, ' Metal'], [0.072949650917907, 0.087910011701061, 0.27105129935471, ' Metal'], [0.080821995557027, 0.042526024983618, 0.2757571006238, ' Ceramic'], [0.066663049523363, 0.065473618345075, 0.23559442915324, ' Metal'], [0.079483108560596, 0.055233353139169, 0.11323980734593, ' Plastic'], [0.065418112933554, 0.038983836468211, 0.19226271356601, ' Ceramic'], [0.05475818252451, 0.037793937895913, 0.13647211399923, ' Ceramic'], [0.06474901702763, 0.059594514474874, 0.22001702459756, ' Metal'],  ...

# %%
#Training the program data by giving data itself and predicting
Train_program_data = program_data
Distance =[]
for i in range(0 , len(Train_program_data)):
    col = []
    for j in range(0,len(Train_program_data)):
        if i==j:
             j=j+1
        else:
                dist_label =[]
                dist_label.append(Train_program_data[j][3])
                X=Train_program_data[i][0]
                Y=Train_program_data[i][1]
                Z=Train_program_data[i][2]
                x=Train_program_data[j][0]
                y=Train_program_data[j][1]
                z=Train_program_data[j][2]
                dist = np.sqrt((X-x)**2 + (Y-y)**2 + (Z-z)**2)
                dist_label.append(dist)
                col.append(dist_label)
    Distance.append(col)
print("\n DISTANCE MATRIX \n")
print(Distance)
print("\n")

# %%
#We have measured the distances and also labeled the points now we need to extract the distance arrange it into 
#ascending order and the again attached the labels so that we can get newly trained data set
def bubblesort(arr):   
    n = len(arr)
    # For loop to traverse through all
    # element in an array
    for i in range(n):
        for j in range(0, n - i - 1):
             
            # Range of the array is from 0 to n-i-1
            # Swap the elements if the element found
            #is greater than the adjacent element
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                
only_dist =[]
for i in range(0, len(Distance)):
    cols=[]
    for j in range(0 , len(Distance[i])):
        cols.append(Distance[i][j][1])
    bubblesort(cols)
    only_dist.append(cols)
print(only_dist)
# Out:
# [[0.029865896676656425, 0.041048196992840076, 0.049550178335158505, 0.05669553212060376, 0.062351416397756654, 0.07745253131411604, 0.07893535522645392, 0.08414639785193075, 0.0877469565348022, 0.09097338400492193, 0.0935992030723897, 0.09676575322852574, 0.10022965218728348, 0.1036376456365194, 0.10616868217993887, 0.10666004847623738, 0.11667741680561848, 0.13730604888485323, 0.14222063349252134, 0.1437238873943267, 0.14619991182839268, 0.15129098693453816, 0.15233336159291777, 0.15279408814449522, 0.15507917212563435, 0.1628694877379771, 0.16314926565961896, 0.16707981499114857, 0.1738321400181486, 0.17556669528340224, 0.1768441700287177, 0.18540768851659614, 0.18879695883879338, 0.19921357109201007, 0.20031906828952775, 0.2045812398144893, 0.20612507304
Metal', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Metal', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic'], [' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic'], [' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Cera ...

# %%
#We will now predict by K nearest Neighbours
predict_1 = []
for i in range(0 , len(data_dist_label)):
     predict_1.append(data_dist_label[i][0])
print(predict_1)
# Out:
# [' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic']

# %%
#We will now find the accuracy for K=1
ps=0 #predicted Successfully
pu=0 #Predicted Unsuccessfully
for i in range(0,len(program_data)):
    if predict_1[i] == program_data[i][3]:
            ps=ps+1
    else :
        pu=pu+1
accuracy_1 = ps/(ps+pu)
print("\nAccuracy for KNN with 1 neighbour")
print("Predicted unsuccesfully  "+str(pu))
print("Predicted Successfully  " + str(ps))
print("Accuracy "+str(accuracy_1*100)+"%")
# Out:
# Accuracy for KNN with 1 neighbour
# Predicted unsuccesfully  15
# Predicted Successfully  105
# Accuracy 87.5%

# %%
a = " Metal"
b = " Plastic"
c = " Ceramic"

#We will now intialize the predictions for KNN value 3
predict_3 =[]
for i in range(0 , len(data_dist_label)):
    x=0
    y=0
    z=0
    cols=[]
    for j in range(0 , 3):
        if (str(data_dist_label[i][j]) == a):
            x=x+1
        if(str(data_dist_label[i][j])==b):
            y=y+1
        if(str(data_dist_label[i][j])==c):
            z=z+1
 
    if (x >= y) and (y >= z):
           largest = a
    elif (y >= x) and (y >= z):
        largest = b
    else:
        largest = c
    predict_3.append(largest)
print(predict_3)
# Out:
# [' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Metal', ' Metal', ' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Metal', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic']

# %%
#Now we will find the accuracy for KNN with 3 neighbours

ps=0 #predicted Successfully
pu=0 #Predicted Unsuccessfully
for i in range(0,len(program_data)):
    if predict_3[i] == program_data[i][3]:
            ps=ps+1
    else :
        pu=pu+1
accuracy_1 = ps/(ps+pu)
print("\nAccuracy for KNN with 3 neighbour")
print("Predicted unsuccesfully  "+str(pu))
print("Predicted Successfully  " + str(ps))
print("Accuracy "+str(accuracy_1*100)+"%")
# Out:
# Accuracy for KNN with 3 neighbour
# Predicted unsuccesfully  22
# Predicted Successfully  98
# Accuracy 81.66666666666667%

# %%
#We will now intialize the predictions for KNN value 3
predict_5 =[]
for i in range(0 , len(data_dist_label)):
    x=0
    y=0
    z=0
    cols=[]
    for j in range(0 , 5):
        if (str(data_dist_label[i][j]) == a):
            x=x+1
        if(str(data_dist_label[i][j])==b):
            y=y+1
        if(str(data_dist_label[i][j])==c):
            z=z+1
 
    if (x >= y) and (y >= z):
           largest = a
    elif (y >= x) and (y >= z):
        largest = b
    else:
        largest = c
    predict_5.append(largest)
print(predict_5)
# Out:
# [' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Metal', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Metal', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Ceramic', ' Ceramic', ' Ceramic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Ceramic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Plastic', ' Metal', ' Plastic', ' Plastic', ' Plastic', ' Plastic']

# %%
#Now we will find the accuracy for KNN with 3 neighbours

ps=0 #predicted Successfully
pu=0 #Predicted Unsuccessfully
for i in range(0,len(program_data)):
    if predict_5[i] == program_data[i][3]:
            ps=ps+1
    else :
        pu=pu+1
accuracy_1 = ps/(ps+pu)
print("\nAccuracy for KNN with 5 neighbour")
print("Predicted unsuccesfully  "+str(pu))
print("Predicted Successfully  " + str(ps))
print("Accuracy "+str(accuracy_1*100)+"%")
# Out:
# Accuracy for KNN with 5 neighbour
# Predicted unsuccesfully  32
# Predicted Successfully  88
# Accuracy 73.33333333333333%

# %% [markdown]
# As seeing the results are astonishing as we can see that this KNN model has the highest accuracy recorded in this assignment that when N=1 , this KNN model shows accuracy of 87.5%
